# %% [markdown]
# <div style="font-family: SimSun, 宋体, serif; font-size: 10.5pt; line-height: 1.5; margin: 0; text-align: justify;">Task 1：获取沪深股市某一股票过去一年每个交易日数据，绘制每日收盘价曲线，并保存 CSV。</div>

# %%
import os
from datetime import datetime, timedelta
import tushare as ts
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimSun']
plt.rcParams['axes.unicode_minus'] = False

token = os.getenv('TUSHARE_TOKEN')
assert token, '请先设置环境变量 TUSHARE_TOKEN'
ts.set_token(token)
pro = ts.pro_api()

ts_code = '000001.SZ'
end_date = datetime.today().strftime('%Y%m%d')
start_date = (datetime.today() - timedelta(days=365)).strftime('%Y%m%d')

df = pro.daily(ts_code=ts_code, start_date=start_date, end_date=end_date)
df = df.sort_values('trade_date')
df.to_csv('../task1_daily_data.csv', index=False, encoding='utf-8-sig')
display(df.head())

plt.figure(figsize=(10, 5))
plt.plot(pd.to_datetime(df['trade_date']), df['close'], label='close')
plt.title(f'{ts_code} 每日收盘价')
plt.xlabel('日期')
plt.ylabel('收盘价')
plt.legend()
plt.grid(True)
plt.show()
